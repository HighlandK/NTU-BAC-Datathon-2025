# %% [markdown]
# # Moomoo and Friends' Code!

# %% [markdown]
# ## Let's import the data!

# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt 
sb.set() # set the default Seaborn style for graphics
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.tree import plot_tree
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import seaborn as sns
import numpy as np
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# %%
#Similarly, you'll need to change the file location to match your own for this to work
data = pd.read_csv('C:/Users/zitin/Documents/BAC Datathon/Theme 1.csv')
data.head()
# Out:
#    Customer_ID  Age  Gender Income_Level Marital_Status Education_Level  \
# 0  37-611-6911   22  Female       Middle        Married      Bachelor's
# 1  29-392-9296   49    Male         High        Married     High School
# 2  84-649-5117   24  Female       Middle         Single        Master's
# 3  48-980-6078   29  Female       Middle         Single        Master's
# 4  91-170-9072   33  Female       Middle        Widowed     High School
#
#   Occupation  Location     Purchase_Category Purchase_Amount  ...  \
# 0     Middle      Évry  Gardening & Outdoors        $333.80   ...
# 1       High  Huocheng      Food & Beverages        $222.22   ...
# 2       High    Huzhen       Office Supplies        $426.22   ...
# 3     Middle    Wiwilí       Home Appliances        $101.31   ...
# 4     Middle      Nara             Furniture        $211.70   ...
#
#    Customer_Satisfaction Engagement_with_Ads  Device_Used_for_Shopping  \
# 0                      7                 NaN                    Tablet
# 1                      5                High                    Tablet
# 2                      7                 Low                Smartphone
# 3                      1                 NaN                Smartphone
# 4                     10                 NaN                Smartphone
#
#    Payment_Method  Time_of_Purchase Discount_Used  \
# 0     Credit Card          3/1/2024          True
# 1          PayPal         4/16/2024          True
# 2      Debit Card         3/15/2024          True
# 3           Other         10/4/2024          True
# 4      Debit Card         1/30/2024         False
#
#   Customer_Loyalty_Program_Member  Purchase_Intent  Shipping_Preference  \
# 0                           False       Need-based        No Preference
# 1                           False      Wants-based             Standard
# 2                            True        Impulsive        No Preference
# 3                            True       Need-based              Express
# 4                           False      Wants-based        No Preference
#
#   Time_to_Decision
# 0                2
# 1                6
# 2                3
# 3               10
# 4                4
#
# [5 rows x 28 columns]

# %%
print("Data type : ", type(data))
print("Data dims : ", data.shape)
print(data.dtypes)
# Out:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  (1000, 28)
# Customer_ID                               object
# Age                                        int64
# Gender                                    object
# Income_Level                              object
# Marital_Status                            object
# Education_Level                           object
# Occupation                                object
# Location                                  object
# Purchase_Category                         object
# Purchase_Amount                           object
# Frequency_of_Purchase                      int64
# Purchase_Channel                          object
# Brand_Loyalty                              int64
# Product_Rating                             int64
# Time_Spent_on_Product_Research(hours)    float64
# Social_Media_Influence                    object
# Discount_Sensitivity                      object
# Return_Rate                                int64
# Customer_Satisfaction                      int64
# Engagement_with_Ads                       object
# Device_Used_for_Shopping                  object
# Payment_Method                            object
# Time_of_Purchase                          object
# Discount_Used                               bool
# Customer_Loyalty_Program_Member             bool
# Purchase_Intent                           object
# Shipping_Preference                       object
# Time_to_Decision                           int64
# dtype: object

# %% [markdown]
# ### We need to clean Purchase_Amount, so it can be treated as a continuous variable, a float

# %%
data["Purchase_Amount"] = (
    data["Purchase_Amount"]
    .replace('[\$,]', '', regex=True)  # removes $ and ,
    .astype(float)
)

# %% [markdown]
# # Let's try using a Classification Tree model to predict Purchase Intent

# %%
# Extract Response and Predictors
y = pd.DataFrame(data['Purchase_Intent']) #Response
X = data.drop(["Purchase_Intent","Customer_ID","Return_Rate","Time_of_Purchase"], axis=1) #Predictors

#Identify categorical and numerical columns
categorical_cols = X.select_dtypes(include=["object", "category"]).columns
numeric_cols = X.select_dtypes(include=["int64", "float64"]).columns

print("Categorical variables:", categorical_cols.tolist())
print("Numeric variables:", numeric_cols.tolist())

#Convert categorical variables into numbers
encoder = OneHotEncoder(drop="first", handle_unknown="ignore", sparse_output=False)
X_encoded = pd.DataFrame(
    encoder.fit_transform(X[categorical_cols]),
    columns=encoder.get_feature_names_out(categorical_cols),
    index=X.index
)

#Combine 
X_final = pd.concat([X[numeric_cols].reset_index(drop=True), X_encoded.reset_index(drop=True)], axis=1)

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(X_final, y, test_size = 0.25)

# Decision Tree using Train Data
dectree = DecisionTreeClassifier(max_depth = 15)  # create the decision tree object
dectree.fit(X_train, y_train)                    # train the decision tree model

# Predict Response corresponding to Predictors
y_train_pred = dectree.predict(X_train)
y_test_pred = dectree.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Classification Accuracy \t:", dectree.score(X_train, y_train))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Classification Accuracy \t:", dectree.score(X_test, y_test))
print()

# Plot the Confusion Matrix for Train and Test
f, axes = plt.subplots(1, 2, figsize=(12, 4))
sb.heatmap(confusion_matrix(y_train, y_train_pred),
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[0])
sb.heatmap(confusion_matrix(y_test, y_test_pred), 
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[1])
# Out:
# Categorical variables: ['Gender', 'Income_Level', 'Marital_Status', 'Education_Level', 'Occupation', 'Location', 'Purchase_Category', 'Purchase_Channel', 'Social_Media_Influence', 'Discount_Sensitivity', 'Engagement_with_Ads', 'Device_Used_for_Shopping', 'Payment_Method', 'Shipping_Preference']
# Numeric variables: ['Age', 'Purchase_Amount', 'Frequency_of_Purchase', 'Brand_Loyalty', 'Product_Rating', 'Time_Spent_on_Product_Research(hours)', 'Customer_Satisfaction', 'Time_to_Decision']
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.9386666666666666
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.264
# <Axes: >

# %%
# Plot the trained Decision Tree
from sklearn.tree import plot_tree

f = plt.figure(figsize=(12,12))
plot_tree(dectree, filled=True, rounded=True, 
          feature_names=X_train.columns.tolist(), 
          class_names=["Wants-based","Impulsive", "Need-based", "Planned"])
# Out:
# [Text(0.6417635335838991, 0.96875, 'Purchase_Amount <= 438.83\ngini = 0.75\nsamples = 750\nvalue = [191, 191, 181, 187]\nclass = Wants-based'),
#  Text(0.32814394398642094, 0.90625, 'Purchase_Amount <= 136.6\ngini = 0.749\nsamples = 650\nvalue = [179, 166, 159, 146]\nclass = Wants-based'),
#  Text(0.10908705140640156, 0.84375, 'Brand_Loyalty <= 2.5\ngini = 0.732\nsamples = 152\nvalue = [36, 36, 54, 26]\nclass = Need-based'),
#  Text(0.055286129970902036, 0.78125, 'Age <= 23.5\ngini = 0.716\nsamples = 58\nvalue = [22, 9, 17, 10]\nclass = Wants-based'),
#  Text(0.038797284190106696, 0.71875, 'Product_Rating <= 3.5\ngini = 0.5\nsamples = 8\nvalue = [4, 4, 0, 0]\nclass = Wants-based'),
#  Text(0.03491755577109602, 0.65625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.04267701260911736, 0.65625, 'Frequency_of_Purchase <= 11.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4, 0, 0]\nclass = Impulsive'),
#  Text(0.038797284190106696, 0.59375, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]\nclass = Impulsive'),
#  Text(0.04655674102812803, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.07177497575169738, 0.71875, 'Purchase_Category_Baby Products <= 0.5\ngini = 0.705\nsamples = 50\nvalue = [18, 5, 17, 10]\nclass = Wants-based'),
#  Text(0.06789524733268672, 0.65625, 'Purchase_Category_Electronics <= 0.5\ngini = 0.695\nsamples = 48\nvalue = [18, 5, 17, 8]\nclass = Wants-based'),
#  Text(0.05431619786614937, 0.59375, 'Purchase_Channel_Mixed <= 0.5\ngini = 0.679\nsamples = 44\nvalue = [18, 3, 15, 8]\nclass = Wants-based'),
#  Text(0.038797284190106696, 0.53125, 'Payment_Method_PayPal <= 0.5\ngini = 0.617\nsamples = 27\nvalue = [10, 1, 13, 3]\nclass = Need-based'),
#  Text(0.031037827352085354, 0.46875, 'Location_Cravo Norte <= 0.5\ngini = 0.566\nsamples = 22\nvalue = [6, 1, 13, 2]\nclass = Need-based'),
#  Text(0.027158098933074686, 0.40625, 'Time_to_Decision <= 10.5\ngini = 0.526\nsamples = 21\nvalue = [6, 0, 13, 2]\nclass = Need-based'),
#  Text(0.019398642095053348, 0.34375, 'Frequency_of_Purchase <= 7.5\ngini = 0.415\nsamples = 17\nvalue = [5, 0, 12, 0]\nclass = Need-based'),
#  Text(0.015518913676042677, 0.28125, 'Discount_Sensitivity_Somewhat Sensitive <= 0.5\ngini = 0.5\nsamples = 10\nvalue = [5, 0, 5, 0]\nclass = Wants-based'),
#  Text(0.011639185257032008, 0.21875, 'Purchase_Amount <= 64.97\ngini = 0.469\nsamples = 8\nvalue = [5, 0, 3, 0]\nclass = Wants-based'),
#  Text(0.007759456838021339, 0.15625, 'Time_to_Decision <= 4.5\ngini = 0.375\nsamples = 4\nvalue = [1, 0, 3, 0]\nclass = Need-based'),
#  Text(0.0038797284190106693, 0.09375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.011639185257032008, 0.09375, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]\nclass = Need-based'),
#  Text(0.015518913676042677, 0.15625, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.019398642095053348, 0.21875, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]\nclass = Need-based'),
#  Text(0.023278370514064017, 0.28125, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0]\nclass = Need-based'),
#  Text(0.03491755577109602, 0.34375, 'Discount_Sensitivity_Very Sensitive <= 0.5\ngini = 0.625\nsamples = 4\nvalue = [1, 0, 1, 2]\nclass = Planned'),
#  Text(0.031037827352085354, 0.28125, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = Planned'),
#  Text(0.038797284190106696, 0.28125, 'Education_Level_High School <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1, 0]\nclass = Wants-based'),
#  Text(0.03491755577109602, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = Need-based'),
#  Text(0.04267701260911736, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.03491755577109602, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Impulsive'),
#  Text(0.04655674102812803, 0.46875, 'Purchase_Category_Travel & Leisure (Flights <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 0, 0, 1]\nclass = Wants-based'),
#  Text(0.04267701260911736, 0.40625, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.0504364694471387, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = Planned'),
#  Text(0.06983511154219205, 0.53125, 'Income_Level_Middle <= 0.5\ngini = 0.664\nsamples = 17\nvalue = [8, 2, 2, 5]\nclass = Wants-based'),
#  Text(0.06207565470417071, 0.46875, 'Device_Used_for_Shopping_Smartphone <= 0.5\ngini = 0.691\nsamples = 9\nvalue = [2, 1, 2, 4]\nclass = Planned'),
#  Text(0.058195926285160036, 0.40625, 'Purchase_Amount <= 122.505\ngini = 0.571\nsamples = 7\nvalue = [2, 1, 0, 4]\nclass = Planned'),
#  Text(0.05431619786614937, 0.34375, 'Time_to_Decision <= 2.5\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 0, 4]\nclass = Planned'),
#  Text(0.0504364694471387, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Impulsive'),
#  Text(0.058195926285160036, 0.28125, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4]\nclass = Planned'),
#  Text(0.06207565470417071, 0.34375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.06595538312318137, 0.40625, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]\nclass = Need-based'),
#  Text(0.07759456838021339, 0.46875, 'Location_Hengshi <= 0.5\ngini = 0.406\nsamples = 8\nvalue = [6, 1, 0, 1]\nclass = Wants-based'),
#  Text(0.07371483996120272, 0.40625, 'Location_São Mateus do Maranhão <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1, 0, 0]\nclass = Wants-based'),
#  Text(0.06983511154219205, 0.34375, 'gini = 0.0\nsamples = 6\nvalue = [6, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.07759456838021339, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Impulsive'),
#  Text(0.08147429679922405, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = Planned'),
#  Text(0.08147429679922405, 0.59375, 'Frequency_of_Purchase <= 8.0\ngini = 0.5\nsamples = 4\nvalue = [0, 2, 2, 0]\nclass = Impulsive'),
#  Text(0.07759456838021339, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]\nclass = Need-based'),
#  Text(0.08535402521823472, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = Impulsive'),
#  Text(0.07565470417070805, 0.65625, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = Planned'),
#  Text(0.16288797284190107, 0.78125, 'Time_to_Decision <= 1.5\ngini = 0.711\nsamples = 94\nvalue = [14, 27, 37, 16]\nclass = Need-based'),
#  Text(0.15512851600387972, 0.71875, 'Purchase_Amount <= 75.59\ngini = 0.346\nsamples = 9\nvalue = [2, 0, 7, 0]\nclass = Need-based'),
#  Text(0.15124878758486907, 0.65625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.1590082444228904, 0.65625, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0]\nclass = Need-based'),
#  Text(0.1706474296799224, 0.71875, 'Purchase_Category_Clothing <= 0.5\ngini = 0.719\nsamples = 85\nvalue = [12, 27, 30, 16]\nclass = Need-based'),
#  Text(0.16676770126091173, 0.65625, 'Brand_Loyalty <= 4.5\ngini = 0.725\nsamples = 81\nvalue = [12, 27, 26, 16]\nclass = Impulsive'),
#  Text(0.1434287099903007, 0.59375, 'Social_Media_Influence_Low <= 0.5\ngini = 0.7\nsamples = 52\nvalue = [7, 14, 22, 9]\nclass = Need-based'),
#  Text(0.1258486905916586, 0.53125, 'Customer_Satisfaction <= 8.5\ngini = 0.666\nsamples = 41\nvalue = [2, 13, 18, 8]\nclass = Need-based'),
#  Text(0.11008729388942774, 0.46875, 'Payment_Method_Debit Card <= 0.5\ngini = 0.678\nsamples = 32\nvalue = [1, 12, 11, 8]\nclass = Impulsive'),
#  Text(0.0979631425800194, 0.40625, 'Age <= 46.0\ngini = 0.649\nsamples = 24\nvalue = [1, 8, 11, 4]\nclass = Need-based'),
#  Text(0.08535402521823472, 0.34375, 'Gender_Female <= 0.5\ngini = 0.632\nsamples = 19\nvalue = [1, 4, 10, 4]\nclass = Need-based'),
#  Text(0.07177497575169738, 0.28125, "Education_Level_Master's <= 0.5\ngini = 0.66\nsamples = 10\nvalue = [0, 3, 3, 4]\nclass = Planned"),
#  Text(0.06401551891367604, 0.21875, 'Income_Level_Middle <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [0, 1, 1, 4]\nclass = Planned'),
#  Text(0.06013579049466537, 0.15625, 'Purchase_Amount <= 77.18\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0]\nclass = Impulsive'),
#  Text(0.05625606207565471, 0.09375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Impulsive'),
#  Text(0.06401551891367604, 0.09375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = Need-based'),
#  Text(0.06789524733268672, 0.15625, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4]\nclass = Planned'),
#  Text(0.07953443258971872, 0.21875, 'Social_Media_Influence_nan <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [0, 2, 2, 0]\nclass = Impulsive'),
#  Text(0.07565470417070805, 0.15625, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]\nclass = Need-based'),
#  Text(0.08341416100872939, 0.15625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = Impulsive'),
#  Text(0.09893307468477207, 0.28125, 'Purchase_Category_Luxury Goods <= 0.5\ngini = 0.37\nsamples = 9\nvalue = [1, 1, 7, 0]\nclass = Need-based'),
#  Text(0.0950533462657614, 0.21875, 'Purchase_Category_Furniture <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [0, 1, 7, 0]\nclass = Need-based'),
#  Text(0.09117361784675072, 0.15625, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0]\nclass = Need-based'),
#  Text(0.09893307468477207, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Impulsive'),
#  Text(0.10281280310378274, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.11057225994180407, 0.34375, 'Gender_Male <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [0, 4, 1, 0]\nclass = Impulsive'),
#  Text(0.1066925315227934, 0.28125, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]\nclass = Impulsive'),
#  Text(0.11445198836081474, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = Need-based'),
#  Text(0.12221144519883609, 0.40625, 'Age <= 33.0\ngini = 0.5\nsamples = 8\nvalue = [0, 4, 0, 4]\nclass = Impulsive'),
#  Text(0.11833171677982542, 0.34375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0]\nclass = Impulsive'),
#  Text(0.12609117361784675, 0.34375, 'Frequency_of_Purchase <= 8.5\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 0, 4]\nclass = Planned'),
#  Text(0.12221144519883609, 0.28125, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4]\nclass = Planned'),
#  Text(0.12997090203685743, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Impulsive'),
#  Text(0.14161008729388944, 0.46875, 'Purchase_Amount <= 115.53\ngini = 0.37\nsamples = 9\nvalue = [1, 1, 7, 0]\nclass = Need-based'),
#  Text(0.13773035887487875, 0.40625, 'Frequency_of_Purchase <= 11.0\ngini = 0.219\nsamples = 8\nvalue = [0, 1, 7, 0]\nclass = Need-based'),
#  Text(0.1338506304558681, 0.34375, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0]\nclass = Need-based'),
#  Text(0.14161008729388944, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Impulsive'),
#  Text(0.1454898157129001, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.16100872938894278, 0.53125, 'Shipping_Preference_Standard <= 0.5\ngini = 0.645\nsamples = 11\nvalue = [5, 1, 4, 1]\nclass = Wants-based'),
#  Text(0.1571290009699321, 0.46875, 'Purchase_Category_Office Supplies <= 0.5\ngini = 0.612\nsamples = 7\nvalue = [1, 1, 4, 1]\nclass = Need-based'),
#  Text(0.15324927255092144, 0.40625, 'Customer_Satisfaction <= 5.5\ngini = 0.5\nsamples = 6\nvalue = [1, 0, 4, 1]\nclass = Need-based'),
#  Text(0.14936954413191075, 0.34375, 'Age <= 28.0\ngini = 0.32\nsamples = 5\nvalue = [1, 0, 4, 0]\nclass = Need-based'),
#  Text(0.1454898157129001, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.15324927255092144, 0.28125, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0]\nclass = Need-based'),
#  Text(0.1571290009699321, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = Planned'),
#  Text(0.16100872938894278, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Impulsive'),
#  Text(0.16488845780795344, 0.46875, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.1901066925315228, 0.59375, 'Customer_Satisfaction <= 8.5\ngini = 0.692\nsamples = 29\nvalue = [5, 13, 4, 7]\nclass = Impulsive'),
#  Text(0.18040737148399613, 0.53125, 'Payment_Method_Other <= 0.5\ngini = 0.643\nsamples = 23\nvalue = [5, 12, 4, 2]\nclass = Impulsive'),
#  Text(0.1726479146459748, 0.46875, 'Age <= 24.0\ngini = 0.554\nsamples = 19\nvalue = [2, 12, 3, 2]\nclass = Impulsive'),
#  Text(0.1687681862269641, 0.40625, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]\nclass = Need-based'),
#  Text(0.17652764306498545, 0.40625, 'Frequency_of_Purchase <= 10.5\ngini = 0.471\nsamples = 17\nvalue = [2, 12, 1, 2]\nclass = Impulsive'),
#  Text(0.1687681862269641, 0.34375, 'Purchase_Category_Health Supplements <= 0.5\ngini = 0.272\nsamples = 13\nvalue = [0, 11, 1, 1]\nclass = Impulsive'),
#  Text(0.16488845780795344, 0.28125, 'Location_Pameungpeuk <= 0.5\ngini = 0.153\nsamples = 12\nvalue = [0, 11, 0, 1]\nclass = Impulsive'),
#  Text(0.16100872938894278, 0.21875, 'gini = 0.0\nsamples = 11\nvalue = [0, 11, 0, 0]\nclass = Impulsive'),
#  Text(0.1687681862269641, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = Planned'),
#  Text(0.1726479146459748, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = Need-based'),
#  Text(0.1842870999030068, 0.34375, 'Purchase_Channel_Mixed <= 0.5\ngini = 0.625\nsamples = 4\nvalue = [2, 1, 0, 1]\nclass = Wants-based'),
#  Text(0.18040737148399613, 0.28125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.18816682832201745, 0.28125, 'Occupation_Middle <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1]\nclass = Impulsive'),
#  Text(0.1842870999030068, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Impulsive'),
#  Text(0.19204655674102813, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = Planned'),
#  Text(0.18816682832201745, 0.46875, 'Purchase_Amount <= 53.765\ngini = 0.375\nsamples = 4\nvalue = [3, 0, 1, 0]\nclass = Wants-based'),
#  Text(0.1842870999030068, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = Need-based'),
#  Text(0.19204655674102813, 0.40625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.19980601357904948, 0.53125, 'Gender_Male <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [0, 1, 0, 5]\nclass = Planned'),
#  Text(0.1959262851600388, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Impulsive'),
#  Text(0.20368574199806014, 0.46875, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5]\nclass = Planned'),
#  Text(0.17452715809893307, 0.65625, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0]\nclass = Need-based'),
#  Text(0.5472008365664404, 0.84375, 'Purchase_Amount <= 209.11\ngini = 0.747\nsamples = 498\nvalue = [143, 130, 105, 120]\nclass = Wants-based'),
#  Text(0.36855904461687683, 0.78125, 'Purchase_Category_Books <= 0.5\ngini = 0.71\nsamples = 121\nvalue = [45, 21, 16, 39]\nclass = Wants-based'),
#  Text(0.36467931619786614, 0.71875, 'Age <= 43.5\ngini = 0.715\nsamples = 117\nvalue = [41, 21, 16, 39]\nclass = Wants-based'),
#  Text(0.3355661978661494, 0.65625, 'Customer_Satisfaction <= 9.5\ngini = 0.709\nsamples = 97\nvalue = [30, 18, 12, 37]\nclass = Planned'),
#  Text(0.3200169738118332, 0.59375, 'Purchase_Category_Food & Beverages <= 0.5\ngini = 0.703\nsamples = 90\nvalue = [25, 17, 11, 37]\nclass = Planned'),
#  Text(0.30055771096023276, 0.53125, 'Age <= 39.5\ngini = 0.703\nsamples = 85\nvalue = [21, 17, 11, 36]\nclass = Planned'),
#  Text(0.273278370514064, 0.46875, 'Age <= 34.5\ngini = 0.724\nsamples = 72\nvalue = [18, 16, 11, 27]\nclass = Planned'),
#  Text(0.2419980601357905, 0.40625, "Education_Level_Master's <= 0.5\ngini = 0.695\nsamples = 56\nvalue = [13, 10, 8, 25]\nclass = Planned"),
#  Text(0.22017458777885549, 0.34375, 'Purchase_Amount <= 202.99\ngini = 0.634\nsamples = 33\nvalue = [9, 2, 5, 17]\nclass = Planned'),
#  Text(0.20950533462657614, 0.28125, 'Device_Used_for_Shopping_Tablet <= 0.5\ngini = 0.601\nsamples = 26\nvalue = [4, 2, 5, 15]\nclass = Planned'),
#  Text(0.19980601357904948, 0.21875, 'Social_Media_Influence_Low <= 0.5\ngini = 0.475\nsamples = 20\nvalue = [3, 1, 2, 14]\nclass = Planned'),
#  Text(0.19204655674102813, 0.15625, 'Location_Jaguaruana <= 0.5\ngini = 0.153\nsamples = 12\nvalue = [1, 0, 0, 11]\nclass = Planned'),
#  Text(0.18816682832201745, 0.09375, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 0, 11]\nclass = Planned'),
#  Text(0.1959262851600388, 0.09375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.2075654704170708, 0.15625, 'Product_Rating <= 2.0\ngini = 0.719\nsamples = 8\nvalue = [2, 1, 2, 3]\nclass = Planned'),
#  Text(0.20368574199806014, 0.09375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]\nclass = Need-based'),
#  Text(0.21144519883608148, 0.09375, 'Device_Used_for_Shopping_Smartphone <= 0.5\ngini = 0.611\nsamples = 6\nvalue = [2, 1, 0, 3]\nclass = Planned'),
#  Text(0.2075654704170708, 0.03125, 'gini = 0.444\nsamples = 3\nvalue = [2, 1, 0, 0]\nclass = Wants-based'),
#  Text(0.21532492725509214, 0.03125, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]\nclass = Planned'),
#  Text(0.2192046556741028, 0.21875, 'Purchase_Channel_Online <= 0.5\ngini = 0.667\nsamples = 6\nvalue = [1, 1, 3, 1]\nclass = Need-based'),
#  Text(0.21532492725509214, 0.15625, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]\nclass = Need-based'),
#  Text(0.22308438409311349, 0.15625, 'Income_Level_Middle <= 0.5\ngini = 0.667\nsamples = 3\nvalue = [1, 1, 0, 1]\nclass = Wants-based'),
#  Text(0.2192046556741028, 0.09375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Impulsive'),
#  Text(0.22696411251212414, 0.09375, 'Marital_Status_Widowed <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = Wants-based'),
#  Text(0.22308438409311349, 0.03125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.23084384093113483, 0.03125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = Planned'),
#  Text(0.23084384093113483, 0.28125, 'Marital_Status_Widowed <= 0.5\ngini = 0.408\nsamples = 7\nvalue = [5, 0, 0, 2]\nclass = Wants-based'),
#  Text(0.22696411251212414, 0.21875, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.2347235693501455, 0.21875, 'Product_Rating <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 0, 2]\nclass = Planned'),
#  Text(0.23084384093113483, 0.15625, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = Planned'),
#  Text(0.23860329776915615, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.2638215324927255, 0.34375, 'Income_Level_Middle <= 0.5\ngini = 0.711\nsamples = 23\nvalue = [4, 8, 3, 8]\nclass = Impulsive'),
#  Text(0.2541222114451988, 0.28125, 'Gender_Genderfluid <= 0.5\ngini = 0.653\nsamples = 12\nvalue = [1, 6, 3, 2]\nclass = Impulsive'),
#  Text(0.2502424830261882, 0.21875, 'Age <= 25.5\ngini = 0.54\nsamples = 10\nvalue = [1, 6, 3, 0]\nclass = Impulsive'),
#  Text(0.2463627546071775, 0.15625, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0, 0]\nclass = Impulsive'),
#  Text(0.2541222114451988, 0.15625, 'Purchase_Channel_Online <= 0.5\ngini = 0.56\nsamples = 5\nvalue = [1, 1, 3, 0]\nclass = Need-based'),
#  Text(0.2502424830261882, 0.09375, 'Product_Rating <= 2.0\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3, 0]\nclass = Need-based'),
#  Text(0.2463627546071775, 0.03125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Impulsive'),
#  Text(0.2541222114451988, 0.03125, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]\nclass = Need-based'),
#  Text(0.2580019398642095, 0.09375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.2580019398642095, 0.21875, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = Planned'),
#  Text(0.2735208535402522, 0.28125, 'Age <= 27.5\ngini = 0.595\nsamples = 11\nvalue = [3, 2, 0, 6]\nclass = Planned'),
#  Text(0.26576139670223087, 0.21875, 'Payment_Method_Other <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [3, 0, 0, 2]\nclass = Wants-based'),
#  Text(0.2618816682832202, 0.15625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.2696411251212415, 0.15625, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = Planned'),
#  Text(0.2812803103782735, 0.21875, 'Age <= 32.5\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 0, 4]\nclass = Planned'),
#  Text(0.27740058195926287, 0.15625, 'Purchase_Category_Mobile Accessories <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 0, 1]\nclass = Impulsive'),
#  Text(0.2735208535402522, 0.09375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = Impulsive'),
#  Text(0.2812803103782735, 0.09375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = Planned'),
#  Text(0.2851600387972842, 0.15625, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]\nclass = Planned'),
#  Text(0.30455868089233756, 0.40625, 'Customer_Satisfaction <= 3.5\ngini = 0.711\nsamples = 16\nvalue = [5, 6, 3, 2]\nclass = Impulsive'),
#  Text(0.3006789524733269, 0.34375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0]\nclass = Impulsive'),
#  Text(0.3084384093113482, 0.34375, 'Occupation_Middle <= 0.5\ngini = 0.722\nsamples = 13\nvalue = [5, 3, 3, 2]\nclass = Wants-based'),
#  Text(0.3006789524733269, 0.28125, 'Frequency_of_Purchase <= 9.5\ngini = 0.719\nsamples = 8\nvalue = [1, 2, 3, 2]\nclass = Need-based'),
#  Text(0.2967992240543162, 0.21875, 'Engagement_with_Ads_Medium <= 0.5\ngini = 0.64\nsamples = 5\nvalue = [1, 2, 0, 2]\nclass = Impulsive'),
#  Text(0.2929194956353055, 0.15625, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = Planned'),
#  Text(0.3006789524733269, 0.15625, 'Income_Level_Middle <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0, 0]\nclass = Impulsive'),
#  Text(0.2967992240543162, 0.09375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = Impulsive'),
#  Text(0.30455868089233756, 0.09375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.30455868089233756, 0.21875, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]\nclass = Need-based'),
#  Text(0.31619786614936957, 0.28125, 'Location_Genting <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1, 0, 0]\nclass = Wants-based'),
#  Text(0.3123181377303589, 0.21875, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.3200775945683802, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Impulsive'),
#  Text(0.32783705140640157, 0.46875, 'Location_Nikolayevsk <= 0.5\ngini = 0.462\nsamples = 13\nvalue = [3, 1, 0, 9]\nclass = Planned'),
#  Text(0.3239573229873909, 0.40625, 'Product_Rating <= 3.5\ngini = 0.375\nsamples = 12\nvalue = [3, 0, 0, 9]\nclass = Planned'),
#  Text(0.3200775945683802, 0.34375, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6]\nclass = Planned'),
#  Text(0.32783705140640157, 0.34375, 'Product_Rating <= 4.5\ngini = 0.5\nsamples = 6\nvalue = [3, 0, 0, 3]\nclass = Wants-based'),
#  Text(0.3239573229873909, 0.28125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.3317167798254122, 0.28125, 'Location_Bor <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 0, 0, 3]\nclass = Planned'),
#  Text(0.32783705140640157, 0.21875, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]\nclass = Planned'),
#  Text(0.3355965082444229, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.3317167798254122, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Impulsive'),
#  Text(0.3394762366634336, 0.53125, 'Shipping_Preference_Standard <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 0, 0, 1]\nclass = Wants-based'),
#  Text(0.3355965082444229, 0.46875, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.3433559650824442, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = Planned'),
#  Text(0.3511154219204656, 0.59375, 'Discount_Sensitivity_Very Sensitive <= 0.5\ngini = 0.449\nsamples = 7\nvalue = [5, 1, 1, 0]\nclass = Wants-based'),
#  Text(0.3472356935014549, 0.53125, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.35499515033947626, 0.53125, 'Social_Media_Influence_Medium <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0]\nclass = Impulsive'),
#  Text(0.3511154219204656, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = Need-based'),
#  Text(0.3588748787584869, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Impulsive'),
#  Text(0.3937924345295829, 0.65625, 'Income_Level_Middle <= 0.5\ngini = 0.625\nsamples = 20\nvalue = [11, 3, 4, 2]\nclass = Wants-based'),
#  Text(0.37827352085354027, 0.59375, 'Engagement_with_Ads_Low <= 0.5\ngini = 0.403\nsamples = 12\nvalue = [9, 2, 0, 1]\nclass = Wants-based'),
#  Text(0.3705140640155189, 0.53125, 'Location_Lianghu <= 0.5\ngini = 0.198\nsamples = 9\nvalue = [8, 0, 0, 1]\nclass = Wants-based'),
#  Text(0.36663433559650827, 0.46875, 'gini = 0.0\nsamples = 8\nvalue = [8, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.3743937924345296, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = Planned'),
#  Text(0.3860329776915616, 0.53125, 'Discount_Sensitivity_Somewhat Sensitive <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0, 0]\nclass = Impulsive'),
#  Text(0.3821532492725509, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = Impulsive'),
#  Text(0.38991270611057227, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.4093113482056256, 0.59375, 'Purchase_Amount <= 154.08\ngini = 0.656\nsamples = 8\nvalue = [2, 1, 4, 1]\nclass = Need-based'),
#  Text(0.4015518913676043, 0.53125, 'Education_Level_High School <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 1]\nclass = Wants-based'),
#  Text(0.3976721629485936, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.40543161978661496, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = Planned'),
#  Text(0.41707080504364696, 0.53125, 'Purchase_Category_Travel & Leisure (Flights <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 4, 0]\nclass = Need-based'),
#  Text(0.4131910766246363, 0.46875, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0]\nclass = Need-based'),
#  Text(0.4209505334626576, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Impulsive'),
#  Text(0.37243877303588746, 0.71875, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.7258426285160039, 0.78125, 'Age <= 45.5\ngini = 0.747\nsamples = 377\nvalue = [98, 109, 89, 81]\nclass = Impulsive'),
#  Text(0.6277279340446169, 0.71875, 'Marital_Status_Single <= 0.5\ngini = 0.742\nsamples = 322\nvalue = [89, 96, 78, 59]\nclass = Impulsive'),
#  Text(0.5426770126091174, 0.65625, 'Frequency_of_Purchase <= 3.5\ngini = 0.732\nsamples = 244\nvalue = [72, 81, 52, 39]\nclass = Impulsive'),
#  Text(0.475266731328807, 0.59375, 'Device_Used_for_Shopping_Tablet <= 0.5\ngini = 0.691\nsamples = 48\nvalue = [22, 8, 8, 10]\nclass = Wants-based'),
#  Text(0.44616876818622697, 0.53125, 'Device_Used_for_Shopping_Smartphone <= 0.5\ngini = 0.74\nsamples = 32\nvalue = [10, 7, 6, 9]\nclass = Wants-based'),
#  Text(0.42870999030067897, 0.46875, 'Payment_Method_Credit Card <= 0.5\ngini = 0.68\nsamples = 16\nvalue = [2, 7, 2, 5]\nclass = Impulsive'),
#  Text(0.4190106692531523, 0.40625, 'Customer_Satisfaction <= 7.5\ngini = 0.597\nsamples = 12\nvalue = [2, 7, 1, 2]\nclass = Impulsive'),
#  Text(0.41125121241513096, 0.34375, 'Social_Media_Influence_nan <= 0.5\ngini = 0.37\nsamples = 9\nvalue = [1, 7, 0, 1]\nclass = Impulsive'),
#  Text(0.4073714839961203, 0.28125, 'Time_to_Decision <= 2.0\ngini = 0.219\nsamples = 8\nvalue = [1, 7, 0, 0]\nclass = Impulsive'),
#  Text(0.4034917555771096, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.41125121241513096, 0.21875, 'gini = 0.0\nsamples = 7\nvalue = [0, 7, 0, 0]\nclass = Impulsive'),
#  Text(0.4151309408341416, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = Planned'),
#  Text(0.4267701260911736, 0.34375, 'Purchase_Channel_Mixed <= 0.5\ngini = 0.667\nsamples = 3\nvalue = [1, 0, 1, 1]\nclass = Wants-based'),
#  Text(0.42289039767216297, 0.28125, 'Time_to_Decision <= 11.5\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = Wants-based'),
#  Text(0.4190106692531523, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.4267701260911736, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = Planned'),
#  Text(0.4306498545101843, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = Need-based'),
#  Text(0.4384093113482056, 0.40625, 'Purchase_Category_Sports & Outdoors <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 3]\nclass = Planned'),
#  Text(0.43452958292919497, 0.34375, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]\nclass = Planned'),
#  Text(0.4422890397672163, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = Need-based'),
#  Text(0.463627546071775, 0.46875, 'Purchase_Amount <= 345.745\ngini = 0.625\nsamples = 16\nvalue = [8, 0, 4, 4]\nclass = Wants-based'),
#  Text(0.4539282250242483, 0.40625, 'Product_Rating <= 1.5\ngini = 0.245\nsamples = 7\nvalue = [6, 0, 0, 1]\nclass = Wants-based'),
#  Text(0.45004849660523766, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = Planned'),
#  Text(0.457807953443259, 0.34375, 'gini = 0.0\nsamples = 6\nvalue = [6, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.47332686711930166, 0.40625, 'Purchase_Amount <= 399.83\ngini = 0.642\nsamples = 9\nvalue = [2, 0, 4, 3]\nclass = Need-based'),
#  Text(0.4655674102812803, 0.34375, 'Location_Strabychovo <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 1]\nclass = Need-based'),
#  Text(0.46168768186226966, 0.28125, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0]\nclass = Need-based'),
#  Text(0.469447138700291, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = Planned'),
#  Text(0.481086323957323, 0.34375, 'Time_Spent_on_Product_Research(hours) <= 1.5\ngini = 0.5\nsamples = 4\nvalue = [2, 0, 0, 2]\nclass = Wants-based'),
#  Text(0.4772065955383123, 0.28125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.48496605237633367, 0.28125, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = Planned'),
#  Text(0.504364694471387, 0.53125, 'Purchase_Category_Mobile Accessories <= 0.5\ngini = 0.414\nsamples = 16\nvalue = [12, 1, 2, 1]\nclass = Wants-based'),
#  Text(0.49660523763336567, 0.46875, 'Age <= 42.5\ngini = 0.245\nsamples = 14\nvalue = [12, 0, 2, 0]\nclass = Wants-based'),
#  Text(0.492725509214355, 0.40625, 'Location_Ferreira do Alentejo <= 0.5\ngini = 0.142\nsamples = 13\nvalue = [12, 0, 1, 0]\nclass = Wants-based'),
#  Text(0.48884578079534435, 0.34375, 'gini = 0.0\nsamples = 12\nvalue = [12, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.49660523763336567, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = Need-based'),
#  Text(0.5004849660523764, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = Need-based'),
#  Text(0.5121241513094084, 0.46875, 'Age <= 23.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1]\nclass = Impulsive'),
#  Text(0.5082444228903976, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = Planned'),
#  Text(0.516003879728419, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Impulsive'),
#  Text(0.6100872938894277, 0.59375, 'Purchase_Amount <= 437.35\ngini = 0.724\nsamples = 196\nvalue = [50, 73, 44, 29]\nclass = Impulsive'),
#  Text(0.6062075654704171, 0.53125, 'Purchase_Category_Health Care <= 0.5\ngini = 0.722\nsamples = 193\nvalue = [50, 73, 41, 29]\nclass = Impulsive'),
#  Text(0.5674102812803103, 0.46875, 'Payment_Method_PayPal <= 0.5\ngini = 0.717\nsamples = 184\nvalue = [45, 73, 38, 28]\nclass = Impulsive'),
#  Text(0.5237633365664404, 0.40625, 'Age <= 20.5\ngini = 0.695\nsamples = 143\nvalue = [32, 64, 26, 21]\nclass = Impulsive'),
#  Text(0.5053346265761397, 0.34375, 'Location_Wŏnsan <= 0.5\ngini = 0.198\nsamples = 9\nvalue = [0, 8, 1, 0]\nclass = Impulsive'),
#  Text(0.501454898157129, 0.28125, 'gini = 0.0\nsamples = 8\nvalue = [0, 8, 0, 0]\nclass = Impulsive'),
#  Text(0.5092143549951503, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = Need-based'),
#  Text(0.542192046556741, 0.34375, 'Marital_Status_Widowed <= 0.5\ngini = 0.709\nsamples = 134\nvalue = [32, 56, 25, 21]\nclass = Impulsive'),
#  Text(0.5169738118331717, 0.28125, 'Purchase_Category_Groceries <= 0.5\ngini = 0.733\nsamples = 82\nvalue = [24, 27, 18, 13]\nclass = Impulsive'),
#  Text(0.49757516973811833, 0.21875, 'Payment_Method_Credit Card <= 0.5\ngini = 0.716\nsamples = 74\nvalue = [24, 25, 17, 8]\nclass = Impulsive'),
#  Text(0.48205625606207564, 0.15625, 'Frequency_of_Purchase <= 5.5\ngini = 0.691\nsamples = 51\nvalue = [21, 16, 9, 5]\nclass = Wants-based'),
#  Text(0.4742967992240543, 0.09375, 'Shipping_Preference_Standard <= 0.5\ngini = 0.625\nsamples = 8\nvalue = [0, 4, 2, 2]\nclass = Impulsive'),
#  Text(0.47041707080504364, 0.03125, 'gini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 2]\nclass = Need-based'),
#  Text(0.478176527643065, 0.03125, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]\nclass = Impulsive'),
#  Text(0.489815712900097, 0.09375, 'Purchase_Amount <= 262.255\ngini = 0.652\nsamples = 43\nvalue = [21, 12, 7, 3]\nclass = Wants-based'),
#  Text(0.4859359844810863, 0.03125, 'gini = 0.486\nsamples = 12\nvalue = [8, 1, 3, 0]\nclass = Wants-based'),
#  Text(0.49369544131910764, 0.03125, 'gini = 0.672\nsamples = 31\nvalue = [13, 11, 4, 3]\nclass = Wants-based'),
#  Text(0.513094083414161, 0.15625, 'Purchase_Channel_Mixed <= 0.5\ngini = 0.692\nsamples = 23\nvalue = [3, 9, 8, 3]\nclass = Impulsive'),
#  Text(0.5053346265761397, 0.09375, 'Device_Used_for_Shopping_Tablet <= 0.5\ngini = 0.694\nsamples = 12\nvalue = [3, 1, 5, 3]\nclass = Need-based'),
#  Text(0.501454898157129, 0.03125, 'gini = 0.449\nsamples = 7\nvalue = [1, 1, 5, 0]\nclass = Need-based'),
#  Text(0.5092143549951503, 0.03125, 'gini = 0.48\nsamples = 5\nvalue = [2, 0, 0, 3]\nclass = Planned'),
#  Text(0.5208535402521823, 0.09375, 'Purchase_Category_Electronics <= 0.5\ngini = 0.397\nsamples = 11\nvalue = [0, 8, 3, 0]\nclass = Impulsive'),
#  Text(0.5169738118331717, 0.03125, 'gini = 0.198\nsamples = 9\nvalue = [0, 8, 1, 0]\nclass = Impulsive'),
#  Text(0.524733268671193, 0.03125, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]\nclass = Need-based'),
#  Text(0.5363724539282251, 0.21875, 'Purchase_Channel_Mixed <= 0.5\ngini = 0.531\nsamples = 8\nvalue = [0, 2, 1, 5]\nclass = Planned'),
#  Text(0.5324927255092143, 0.15625, 'Product_Rating <= 2.5\ngini = 0.625\nsamples = 4\nvalue = [0, 2, 1, 1]\nclass = Impulsive'),
#  Text(0.5286129970902037, 0.09375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = Planned'),
#  Text(0.5363724539282251, 0.09375, 'Purchase_Amount <= 317.43\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1, 0]\nclass = Impulsive'),
#  Text(0.5324927255092143, 0.03125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = Need-based'),
#  Text(0.5402521823472357, 0.03125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = Impulsive'),
#  Text(0.5402521823472357, 0.15625, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4]\nclass = Planned'),
#  Text(0.5674102812803103, 0.28125, 'Purchase_Category_Furniture <= 0.5\ngini = 0.624\nsamples = 52\nvalue = [8, 29, 7, 8]\nclass = Impulsive'),
#  Text(0.5635305528612997, 0.21875, 'Age <= 43.5\ngini = 0.592\nsamples = 49\nvalue = [8, 29, 7, 5]\nclass = Impulsive'),
#  Text(0.5596508244422891, 0.15625, 'Discount_Sensitivity_Very Sensitive <= 0.5\ngini = 0.569\nsamples = 47\nvalue = [6, 29, 7, 5]\nclass = Impulsive'),
#  Text(0.5518913676042677, 0.09375, 'Location_Tabonok <= 0.5\ngini = 0.413\nsamples = 28\nvalue = [3, 21, 3, 1]\nclass = Impulsive'),
#  Text(0.5480116391852571, 0.03125, 'gini = 0.37\nsamples = 27\nvalue = [3, 21, 3, 0]\nclass = Impulsive'),
#  Text(0.5557710960232783, 0.03125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = Planned'),
#  Text(0.5674102812803103, 0.09375, 'Device_Used_for_Shopping_Tablet <= 0.5\ngini = 0.709\nsamples = 19\nvalue = [3, 8, 4, 4]\nclass = Impulsive'),
#  Text(0.5635305528612997, 0.03125, 'gini = 0.639\nsamples = 13\nvalue = [3, 6, 0, 4]\nclass = Impulsive'),
#  Text(0.5712900096993211, 0.03125, 'gini = 0.444\nsamples = 6\nvalue = [0, 2, 4, 0]\nclass = Need-based'),
#  Text(0.5674102812803103, 0.15625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.5712900096993211, 0.21875, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]\nclass = Planned'),
#  Text(0.6110572259941804, 0.40625, 'Education_Level_High School <= 0.5\ngini = 0.736\nsamples = 41\nvalue = [13, 9, 12, 7]\nclass = Wants-based'),
#  Text(0.5965082444228904, 0.34375, 'Discount_Sensitivity_Very Sensitive <= 0.5\ngini = 0.691\nsamples = 28\nvalue = [12, 8, 5, 3]\nclass = Wants-based'),
#  Text(0.5868089233753637, 0.28125, 'Customer_Satisfaction <= 4.5\ngini = 0.726\nsamples = 19\nvalue = [4, 7, 5, 3]\nclass = Impulsive'),
#  Text(0.5790494665373423, 0.21875, 'Product_Rating <= 4.5\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 5, 2]\nclass = Need-based'),
#  Text(0.5751697381183317, 0.15625, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0]\nclass = Need-based'),
#  Text(0.5829291949563531, 0.15625, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = Planned'),
#  Text(0.5945683802133851, 0.21875, 'Product_Rating <= 2.5\ngini = 0.542\nsamples = 12\nvalue = [4, 7, 0, 1]\nclass = Impulsive'),
#  Text(0.5906886517943744, 0.15625, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0, 0]\nclass = Impulsive'),
#  Text(0.5984481086323957, 0.15625, 'Purchase_Channel_Online <= 0.5\ngini = 0.571\nsamples = 7\nvalue = [4, 2, 0, 1]\nclass = Wants-based'),
#  Text(0.5945683802133851, 0.09375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.6023278370514064, 0.09375, 'Brand_Loyalty <= 2.5\ngini = 0.625\nsamples = 4\nvalue = [1, 2, 0, 1]\nclass = Impulsive'),
#  Text(0.5984481086323957, 0.03125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = Impulsive'),
#  Text(0.6062075654704171, 0.03125, 'gini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = Wants-based'),
#  Text(0.6062075654704171, 0.28125, 'Time_to_Decision <= 1.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1, 0, 0]\nclass = Wants-based'),
#  Text(0.6023278370514064, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Impulsive'),
#  Text(0.6100872938894277, 0.21875, 'gini = 0.0\nsamples = 8\nvalue = [8, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.6256062075654704, 0.34375, 'Time_to_Decision <= 11.0\ngini = 0.604\nsamples = 13\nvalue = [1, 1, 7, 4]\nclass = Need-based'),
#  Text(0.6217264791464597, 0.28125, 'Purchase_Category_Books <= 0.5\ngini = 0.48\nsamples = 10\nvalue = [1, 1, 7, 1]\nclass = Need-based'),
#  Text(0.6178467507274491, 0.21875, 'Location_Kawangkoan <= 0.5\ngini = 0.37\nsamples = 9\nvalue = [0, 1, 7, 1]\nclass = Need-based'),
#  Text(0.6139670223084384, 0.15625, 'Social_Media_Influence_Medium <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 7, 1]\nclass = Need-based'),
#  Text(0.6100872938894277, 0.09375, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0]\nclass = Need-based'),
#  Text(0.6178467507274491, 0.09375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = Planned'),
#  Text(0.6217264791464597, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Impulsive'),
#  Text(0.6256062075654704, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.6294859359844811, 0.28125, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]\nclass = Planned'),
#  Text(0.6450048496605237, 0.46875, 'Shipping_Preference_No Preference <= 0.5\ngini = 0.568\nsamples = 9\nvalue = [5, 0, 3, 1]\nclass = Wants-based'),
#  Text(0.6372453928225025, 0.40625, 'Frequency_of_Purchase <= 5.0\ngini = 0.278\nsamples = 6\nvalue = [5, 0, 1, 0]\nclass = Wants-based'),
#  Text(0.6333656644034917, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = Need-based'),
#  Text(0.6411251212415131, 0.34375, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.6527643064985451, 0.40625, 'Engagement_with_Ads_nan <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1]\nclass = Need-based'),
#  Text(0.6488845780795345, 0.34375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]\nclass = Need-based'),
#  Text(0.6566440349175557, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = Planned'),
#  Text(0.6139670223084384, 0.53125, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]\nclass = Need-based'),
#  Text(0.7127788554801164, 0.65625, 'Social_Media_Influence_Low <= 0.5\ngini = 0.739\nsamples = 78\nvalue = [17, 15, 26, 20]\nclass = Need-based'),
#  Text(0.6777400581959263, 0.59375, 'Age <= 22.5\ngini = 0.721\nsamples = 57\nvalue = [14, 12, 22, 9]\nclass = Need-based'),
#  Text(0.6605237633365665, 0.53125, 'Engagement_with_Ads_Medium <= 0.5\ngini = 0.403\nsamples = 12\nvalue = [2, 0, 9, 1]\nclass = Need-based'),
#  Text(0.6566440349175557, 0.46875, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 9, 0]\nclass = Need-based'),
#  Text(0.6644034917555771, 0.46875, 'Purchase_Category_Food & Beverages <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 1]\nclass = Wants-based'),
#  Text(0.6605237633365665, 0.40625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.6682832201745877, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = Planned'),
#  Text(0.6949563530552861, 0.53125, 'Frequency_of_Purchase <= 11.5\ngini = 0.743\nsamples = 45\nvalue = [12, 12, 13, 8]\nclass = Need-based'),
#  Text(0.6910766246362755, 0.46875, 'Customer_Satisfaction <= 1.5\ngini = 0.744\nsamples = 42\nvalue = [12, 12, 10, 8]\nclass = Wants-based'),
#  Text(0.6760426770126091, 0.40625, 'Payment_Method_Credit Card <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 4, 0]\nclass = Need-based'),
#  Text(0.6721629485935985, 0.34375, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0]\nclass = Need-based'),
#  Text(0.6799224054316197, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Impulsive'),
#  Text(0.7061105722599418, 0.40625, 'Purchase_Amount <= 300.69\ngini = 0.733\nsamples = 37\nvalue = [12, 11, 6, 8]\nclass = Wants-based'),
#  Text(0.6876818622696411, 0.34375, 'Device_Used_for_Shopping_Tablet <= 0.5\ngini = 0.604\nsamples = 15\nvalue = [3, 8, 0, 4]\nclass = Impulsive'),
#  Text(0.6799224054316197, 0.28125, 'Payment_Method_PayPal <= 0.5\ngini = 0.444\nsamples = 9\nvalue = [3, 6, 0, 0]\nclass = Impulsive'),
#  Text(0.6760426770126091, 0.21875, 'Purchase_Category_Hotels <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6, 0, 0]\nclass = Impulsive'),
#  Text(0.6721629485935985, 0.15625, 'gini = 0.0\nsamples = 6\nvalue = [0, 6, 0, 0]\nclass = Impulsive'),
#  Text(0.6799224054316197, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.6838021338506305, 0.21875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.6954413191076625, 0.28125, 'Location_Bucaramanga <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 0, 4]\nclass = Planned'),
#  Text(0.6915615906886518, 0.21875, 'Purchase_Category_Beauty & Personal Care <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 0, 4]\nclass = Planned'),
#  Text(0.6876818622696411, 0.15625, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4]\nclass = Planned'),
#  Text(0.6954413191076625, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Impulsive'),
#  Text(0.6993210475266731, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Impulsive'),
#  Text(0.7245392822502424, 0.34375, 'Purchase_Category_Travel & Leisure (Flights <= 0.5\ngini = 0.707\nsamples = 22\nvalue = [9, 3, 6, 4]\nclass = Wants-based'),
#  Text(0.7206595538312318, 0.28125, 'Brand_Loyalty <= 3.5\ngini = 0.695\nsamples = 20\nvalue = [9, 3, 4, 4]\nclass = Wants-based'),
#  Text(0.7109602327837051, 0.21875, 'Time_to_Decision <= 8.5\ngini = 0.735\nsamples = 14\nvalue = [4, 2, 4, 4]\nclass = Wants-based'),
#  Text(0.7032007759456838, 0.15625, 'Occupation_Middle <= 0.5\ngini = 0.625\nsamples = 8\nvalue = [4, 2, 0, 2]\nclass = Wants-based'),
#  Text(0.6993210475266731, 0.09375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = Impulsive'),
#  Text(0.7070805043646945, 0.09375, 'Purchase_Amount <= 375.955\ngini = 0.444\nsamples = 6\nvalue = [4, 0, 0, 2]\nclass = Wants-based'),
#  Text(0.7032007759456838, 0.03125, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.7109602327837051, 0.03125, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = Planned'),
#  Text(0.7187196896217265, 0.15625, "Education_Level_Master's <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 4, 2]\nclass = Need-based"),
#  Text(0.7148399612027158, 0.09375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = Planned'),
#  Text(0.7225994180407371, 0.09375, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0]\nclass = Need-based'),
#  Text(0.7303588748787585, 0.21875, 'Location_San Luis <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1, 0, 0]\nclass = Wants-based'),
#  Text(0.7264791464597479, 0.15625, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.7342386032977691, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Impulsive'),
#  Text(0.7284190106692532, 0.28125, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]\nclass = Need-based'),
#  Text(0.6988360814742968, 0.46875, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]\nclass = Need-based'),
#  Text(0.7478176527643065, 0.59375, 'Frequency_of_Purchase <= 2.5\ngini = 0.649\nsamples = 21\nvalue = [3, 3, 4, 11]\nclass = Planned'),
#  Text(0.7439379243452958, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.7516973811833172, 0.53125, 'Customer_Satisfaction <= 7.5\ngini = 0.593\nsamples = 19\nvalue = [1, 3, 4, 11]\nclass = Planned'),
#  Text(0.7478176527643065, 0.46875, 'Time_to_Decision <= 9.0\ngini = 0.708\nsamples = 12\nvalue = [1, 3, 4, 4]\nclass = Need-based'),
#  Text(0.7361784675072744, 0.40625, 'Discount_Sensitivity_Somewhat Sensitive <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [0, 1, 4, 1]\nclass = Need-based'),
#  Text(0.7322987390882638, 0.34375, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0]\nclass = Need-based'),
#  Text(0.7400581959262852, 0.34375, 'Location_Jackson <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1]\nclass = Impulsive'),
#  Text(0.7361784675072744, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Impulsive'),
#  Text(0.7439379243452958, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = Planned'),
#  Text(0.7594568380213385, 0.40625, 'Location_Vidual <= 0.5\ngini = 0.611\nsamples = 6\nvalue = [1, 2, 0, 3]\nclass = Planned'),
#  Text(0.7555771096023278, 0.34375, 'Time_Spent_on_Product_Research(hours) <= 1.5\ngini = 0.48\nsamples = 5\nvalue = [0, 2, 0, 3]\nclass = Planned'),
#  Text(0.7516973811833172, 0.28125, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = Planned'),
#  Text(0.7594568380213385, 0.28125, 'Purchase_Amount <= 298.525\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 0, 1]\nclass = Impulsive'),
#  Text(0.7555771096023278, 0.21875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = Impulsive'),
#  Text(0.7633365664403492, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = Planned'),
#  Text(0.7633365664403492, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.7555771096023278, 0.46875, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7]\nclass = Planned'),
#  Text(0.8239573229873909, 0.71875, 'Payment_Method_PayPal <= 0.5\ngini = 0.717\nsamples = 55\nvalue = [9, 13, 11, 22]\nclass = Planned'),
#  Text(0.8031037827352085, 0.65625, 'Engagement_with_Ads_nan <= 0.5\ngini = 0.743\nsamples = 44\nvalue = [8, 12, 11, 13]\nclass = Planned'),
#  Text(0.7846750727449079, 0.59375, 'Product_Rating <= 1.5\ngini = 0.701\nsamples = 32\nvalue = [4, 11, 5, 12]\nclass = Planned'),
#  Text(0.7749757516973812, 0.53125, 'Age <= 49.5\ngini = 0.37\nsamples = 9\nvalue = [1, 0, 1, 7]\nclass = Planned'),
#  Text(0.7710960232783706, 0.46875, 'Purchase_Category_Beauty & Personal Care <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 1, 7]\nclass = Planned'),
#  Text(0.7672162948593598, 0.40625, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7]\nclass = Planned'),
#  Text(0.7749757516973812, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = Need-based'),
#  Text(0.7788554801163918, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.7943743937924346, 0.53125, 'Purchase_Amount <= 328.27\ngini = 0.677\nsamples = 23\nvalue = [3, 11, 4, 5]\nclass = Impulsive'),
#  Text(0.7866149369544132, 0.46875, 'Frequency_of_Purchase <= 3.5\ngini = 0.34\nsamples = 10\nvalue = [0, 8, 1, 1]\nclass = Impulsive'),
#  Text(0.7827352085354026, 0.40625, 'Purchase_Category_Clothing <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1]\nclass = Need-based'),
#  Text(0.7788554801163918, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = Need-based'),
#  Text(0.7866149369544132, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = Planned'),
#  Text(0.7904946653734238, 0.40625, 'gini = 0.0\nsamples = 8\nvalue = [0, 8, 0, 0]\nclass = Impulsive'),
#  Text(0.8021338506304558, 0.46875, 'Social_Media_Influence_Medium <= 0.5\ngini = 0.746\nsamples = 13\nvalue = [3, 3, 3, 4]\nclass = Planned'),
#  Text(0.7982541222114452, 0.40625, 'Discount_Sensitivity_Very Sensitive <= 0.5\ngini = 0.72\nsamples = 10\nvalue = [3, 3, 3, 1]\nclass = Wants-based'),
#  Text(0.7943743937924346, 0.34375, 'Customer_Satisfaction <= 2.5\ngini = 0.688\nsamples = 8\nvalue = [1, 3, 3, 1]\nclass = Impulsive'),
#  Text(0.7866149369544132, 0.28125, 'Engagement_with_Ads_Low <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = Wants-based'),
#  Text(0.7827352085354026, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.7904946653734238, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = Planned'),
#  Text(0.8021338506304558, 0.28125, 'Discount_Sensitivity_Somewhat Sensitive <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [0, 3, 3, 0]\nclass = Impulsive'),
#  Text(0.7982541222114452, 0.21875, 'Purchase_Category_Home Appliances <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [0, 3, 1, 0]\nclass = Impulsive'),
#  Text(0.7943743937924346, 0.15625, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0]\nclass = Impulsive'),
#  Text(0.8021338506304558, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = Need-based'),
#  Text(0.8060135790494666, 0.21875, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]\nclass = Need-based'),
#  Text(0.8021338506304558, 0.34375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.8060135790494666, 0.40625, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]\nclass = Planned'),
#  Text(0.8215324927255092, 0.59375, 'Age <= 48.5\ngini = 0.625\nsamples = 12\nvalue = [4, 1, 6, 1]\nclass = Need-based'),
#  Text(0.8137730358874878, 0.53125, 'Purchase_Category_Food & Beverages <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [2, 0, 6, 0]\nclass = Need-based'),
#  Text(0.8098933074684772, 0.46875, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0]\nclass = Need-based'),
#  Text(0.8176527643064986, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.8292919495635306, 0.53125, 'Brand_Loyalty <= 3.0\ngini = 0.625\nsamples = 4\nvalue = [2, 1, 0, 1]\nclass = Wants-based'),
#  Text(0.8254122211445198, 0.46875, 'Social_Media_Influence_nan <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1]\nclass = Impulsive'),
#  Text(0.8215324927255092, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Impulsive'),
#  Text(0.8292919495635306, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = Planned'),
#  Text(0.8331716779825412, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.8448108632395732, 0.65625, 'Location_Proletarsk <= 0.5\ngini = 0.314\nsamples = 11\nvalue = [1, 1, 0, 9]\nclass = Planned'),
#  Text(0.8409311348205626, 0.59375, 'Location_Adelaide <= 0.5\ngini = 0.18\nsamples = 10\nvalue = [1, 0, 0, 9]\nclass = Planned'),
#  Text(0.8370514064015518, 0.53125, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9]\nclass = Planned'),
#  Text(0.8448108632395732, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.8486905916585838, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Impulsive'),
#  Text(0.9553831231813773, 0.90625, 'Engagement_with_Ads_Medium <= 0.5\ngini = 0.707\nsamples = 100\nvalue = [12, 25, 22, 41]\nclass = Planned'),
#  Text(0.930164888457808, 0.84375, 'Frequency_of_Purchase <= 9.5\ngini = 0.729\nsamples = 74\nvalue = [10, 22, 18, 24]\nclass = Planned'),
#  Text(0.9107662463627546, 0.78125, 'Payment_Method_Debit Card <= 0.5\ngini = 0.73\nsamples = 54\nvalue = [8, 18, 16, 12]\nclass = Impulsive'),
#  Text(0.895247332686712, 0.71875, 'Marital_Status_Widowed <= 0.5\ngini = 0.733\nsamples = 45\nvalue = [8, 11, 16, 10]\nclass = Need-based'),
#  Text(0.8758486905916586, 0.65625, 'Product_Rating <= 2.5\ngini = 0.746\nsamples = 35\nvalue = [7, 9, 9, 10]\nclass = Planned'),
#  Text(0.8603297769156159, 0.59375, 'Brand_Loyalty <= 3.5\ngini = 0.627\nsamples = 13\nvalue = [2, 3, 1, 7]\nclass = Planned'),
#  Text(0.8525703200775946, 0.53125, 'Purchase_Amount <= 442.7\ngini = 0.37\nsamples = 9\nvalue = [0, 1, 1, 7]\nclass = Planned'),
#  Text(0.8486905916585838, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = Need-based'),
#  Text(0.8564500484966052, 0.46875, 'Purchase_Category_Jewelry & Accessories <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [0, 1, 0, 7]\nclass = Planned'),
#  Text(0.8525703200775946, 0.40625, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7]\nclass = Planned'),
#  Text(0.8603297769156159, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Impulsive'),
#  Text(0.8680892337536372, 0.53125, 'Discount_Sensitivity_Somewhat Sensitive <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2, 0, 0]\nclass = Wants-based'),
#  Text(0.8642095053346266, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = Impulsive'),
#  Text(0.871968962172648, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.8913676042677012, 0.59375, 'Time_Spent_on_Product_Research(hours) <= 0.65\ngini = 0.723\nsamples = 22\nvalue = [5, 6, 8, 3]\nclass = Need-based'),
#  Text(0.88360814742968, 0.53125, 'Age <= 26.5\ngini = 0.444\nsamples = 6\nvalue = [0, 4, 0, 2]\nclass = Impulsive'),
#  Text(0.8797284190106692, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = Planned'),
#  Text(0.8874878758486906, 0.46875, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]\nclass = Impulsive'),
#  Text(0.8991270611057226, 0.53125, 'Social_Media_Influence_nan <= 0.5\ngini = 0.633\nsamples = 16\nvalue = [5, 2, 8, 1]\nclass = Need-based'),
#  Text(0.895247332686712, 0.46875, 'Gender_Male <= 0.5\ngini = 0.568\nsamples = 13\nvalue = [2, 2, 8, 1]\nclass = Need-based'),
#  Text(0.8874878758486906, 0.40625, 'Location_São Roque <= 0.5\ngini = 0.34\nsamples = 10\nvalue = [0, 1, 8, 1]\nclass = Need-based'),
#  Text(0.88360814742968, 0.34375, 'Frequency_of_Purchase <= 2.5\ngini = 0.198\nsamples = 9\nvalue = [0, 1, 8, 0]\nclass = Need-based'),
#  Text(0.8797284190106692, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Impulsive'),
#  Text(0.8874878758486906, 0.28125, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0]\nclass = Need-based'),
#  Text(0.8913676042677012, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = Planned'),
#  Text(0.9030067895247332, 0.40625, 'Customer_Satisfaction <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1, 0, 0]\nclass = Wants-based'),
#  Text(0.8991270611057226, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Impulsive'),
#  Text(0.906886517943744, 0.34375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.9030067895247332, 0.46875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.9146459747817652, 0.65625, 'Product_Rating <= 4.5\ngini = 0.46\nsamples = 10\nvalue = [1, 2, 7, 0]\nclass = Need-based'),
#  Text(0.9107662463627546, 0.59375, 'Purchase_Category_Luxury Goods <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [1, 0, 7, 0]\nclass = Need-based'),
#  Text(0.906886517943744, 0.53125, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0]\nclass = Need-based'),
#  Text(0.9146459747817652, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.918525703200776, 0.59375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = Impulsive'),
#  Text(0.9262851600387972, 0.71875, 'Marital_Status_Widowed <= 0.5\ngini = 0.346\nsamples = 9\nvalue = [0, 7, 0, 2]\nclass = Impulsive'),
#  Text(0.9224054316197866, 0.65625, 'gini = 0.0\nsamples = 7\nvalue = [0, 7, 0, 0]\nclass = Impulsive'),
#  Text(0.930164888457808, 0.65625, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = Planned'),
#  Text(0.9495635305528612, 0.78125, 'Time_to_Decision <= 8.5\ngini = 0.58\nsamples = 20\nvalue = [2, 4, 2, 12]\nclass = Planned'),
#  Text(0.94180407371484, 0.71875, 'Location_Zaječov <= 0.5\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 1, 8]\nclass = Planned'),
#  Text(0.9379243452958292, 0.65625, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8]\nclass = Planned'),
#  Text(0.9456838021338506, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = Need-based'),
#  Text(0.9573229873908826, 0.71875, 'Shipping_Preference_No Preference <= 0.5\ngini = 0.694\nsamples = 11\nvalue = [2, 4, 1, 4]\nclass = Impulsive'),
#  Text(0.953443258971872, 0.65625, 'Income_Level_Middle <= 0.5\ngini = 0.656\nsamples = 8\nvalue = [2, 1, 1, 4]\nclass = Planned'),
#  Text(0.9495635305528612, 0.59375, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4]\nclass = Planned'),
#  Text(0.9573229873908826, 0.59375, 'Education_Level_High School <= 0.5\ngini = 0.625\nsamples = 4\nvalue = [2, 1, 1, 0]\nclass = Wants-based'),
#  Text(0.953443258971872, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.9612027158098934, 0.53125, 'Purchase_Category_Packages) <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0]\nclass = Impulsive'),
#  Text(0.9573229873908826, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Impulsive'),
#  Text(0.965082444228904, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = Need-based'),
#  Text(0.9612027158098934, 0.65625, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0]\nclass = Impulsive'),
#  Text(0.9806013579049466, 0.84375, 'Time_Spent_on_Product_Research(hours) <= 0.1\ngini = 0.53\nsamples = 26\nvalue = [2, 3, 4, 17]\nclass = Planned'),
#  Text(0.9689621726479146, 0.78125, 'Customer_Satisfaction <= 5.5\ngini = 0.64\nsamples = 5\nvalue = [0, 2, 2, 1]\nclass = Impulsive'),
#  Text(0.965082444228904, 0.71875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = Impulsive'),
#  Text(0.9728419010669254, 0.71875, 'Gender_Non-binary <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1]\nclass = Need-based'),
#  Text(0.9689621726479146, 0.65625, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]\nclass = Need-based'),
#  Text(0.976721629485936, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = Planned'),
#  Text(0.9922405431619786, 0.78125, 'Location_Fandriana <= 0.5\ngini = 0.399\nsamples = 21\nvalue = [2, 1, 2, 16]\nclass = Planned'),
#  Text(0.988360814742968, 0.71875, 'Location_Seleuš <= 0.5\ngini = 0.34\nsamples = 20\nvalue = [2, 0, 2, 16]\nclass = Planned'),
#  Text(0.9844810863239574, 0.65625, 'Purchase_Category_Home Appliances <= 0.5\ngini = 0.277\nsamples = 19\nvalue = [2, 0, 1, 16]\nclass = Planned'),
#  Text(0.9806013579049466, 0.59375, 'Purchase_Category_Hotels <= 0.5\ngini = 0.198\nsamples = 18\nvalue = [2, 0, 0, 16]\nclass = Planned'),
#  Text(0.976721629485936, 0.53125, 'Location_Shādegān <= 0.5\ngini = 0.111\nsamples = 17\nvalue = [1, 0, 0, 16]\nclass = Planned'),
#  Text(0.9728419010669254, 0.46875, 'gini = 0.0\nsamples = 16\nvalue = [0, 0, 0, 16]\nclass = Planned'),
#  Text(0.9806013579049466, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.9844810863239574, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Wants-based'),
#  Text(0.988360814742968, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = Need-based'),
#  Text(0.9922405431619786, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = Need-based'),
#  Text(0.9961202715809894, 0.71875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Impulsive')]

# %% [markdown]
# # # Let's try using the XGBoost model to predict Purchase Intent

# %%
# Create label encoder
label_encoder = LabelEncoder()

# Convert string labels to numerical labels using ravel() to flatten
y_encoded = label_encoder.fit_transform(y.values.ravel())
y_train_encoded = label_encoder.transform(y_train.values.ravel())
y_test_encoded = label_encoder.transform(y_test.values.ravel())

print("Label mapping:")
for i, class_name in enumerate(label_encoder.classes_):
    print(f"{i} -> {class_name}")

# Now fit XGBoost with encoded labels
xgb = make_pipeline(
    StandardScaler(),
    XGBClassifier(
    n_estimators=300, 
    learning_rate=0.05, 
    max_depth=15, 
    random_state=42
)
)

xgb.fit(X_train, y_train_encoded)

# Make predictions
y_pred_encoded = xgb.predict(X_test)

# Convert predictions back to original labels for interpretation
y_pred_xgb = label_encoder.inverse_transform(y_pred_encoded)

# Calculate accuracy
xgb_accuracy = accuracy_score(y_test, y_pred_xgb)
print(f"XGBoost Accuracy: {xgb_accuracy:.4f}")

# Plot confusion matrix with original labels
cm_xgb = confusion_matrix(y_test, y_pred_xgb)

plt.figure(figsize=(8, 6))
sns.heatmap(cm_xgb, annot=True, fmt='d', cmap='Blues', 
            xticklabels=label_encoder.classes_, 
            yticklabels=label_encoder.classes_)
plt.title(f'XGBoost Confusion Matrix\nAccuracy: {xgb_accuracy:.4f}')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

print("\nXGBoost Classification Report:")
print(classification_report(y_test, y_pred_xgb))
# Out:
# Label mapping:
# 0 -> Impulsive
# 1 -> Need-based
# 2 -> Planned
# 3 -> Wants-based
# XGBoost Accuracy: 0.2480
# XGBoost Classification Report:
#               precision    recall  f1-score   support
#
#    Impulsive       0.23      0.28      0.25        57
#   Need-based       0.28      0.28      0.28        65
#      Planned       0.30      0.26      0.28        66
#  Wants-based       0.19      0.18      0.18        62
#
#     accuracy                           0.25       250
#    macro avg       0.25      0.25      0.25       250
# weighted avg       0.25      0.25      0.25       250

# %% [markdown]
# # Finally, let's try using Logistic Regression

# %%
# Initialize and fit model
model = make_pipeline(
    StandardScaler(),
    LogisticRegression(max_iter=1000)
)
model.fit(X_train, y_train_encoded)

# Predict and evaluate
y_pred = model.predict(X_test)
print(confusion_matrix(y_test_encoded, y_pred))
print(classification_report(y_test_encoded, y_pred))
# Out:
# [[21  4 19 13]
#  [16 17 16 16]
#  [12 21 16 17]
#  [17 19 14 12]]
#               precision    recall  f1-score   support
#
#            0       0.32      0.37      0.34        57
#            1       0.28      0.26      0.27        65
#            2       0.25      0.24      0.24        66
#            3       0.21      0.19      0.20        62
#
#     accuracy                           0.26       250
#    macro avg       0.26      0.27      0.26       250
# weighted avg       0.26      0.26      0.26       250

# %% [markdown]
# # Finally, comparing the models

# %%
# Calculate accuracies for all three models
acc_dectree = dectree.score(X_test, y_test)
acc_xgb = accuracy_score(y_test, y_pred_xgb)
acc_logreg = accuracy_score(y_test_encoded, y_pred)

# Display comparison in a clean table
accuracy_comparison = pd.DataFrame({
    "Model": ["Decision Tree", "XGBoost", "Logistic Regression"],
    "Accuracy": [acc_dectree, acc_xgb, acc_logreg]
})

print("\nModel Accuracy Comparison:")
print(accuracy_comparison.to_string(index=False))
# Out:
# Model Accuracy Comparison:
#               Model  Accuracy
#       Decision Tree     0.264
#             XGBoost     0.248
# Logistic Regression     0.264
